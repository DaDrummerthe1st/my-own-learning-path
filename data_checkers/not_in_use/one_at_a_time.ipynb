# %%
import pandas as pd

# %%
csv = "data/transactions_original.csv"

with open(csv) as csv:
    df = pd.read_csv(csv)

# display(df)
# Out:
# /tmp/ipykernel_10875/1338310835.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv)

# %%
error_builder = pd.DataFrame # add here
run_builder = df # deduct here

def none_check(row, idx):
    v_tr_id, v_time, v_amount, v_curr, v_s_acc, v_r_acc, v_s_country, v_s_mun, v_r_country, v_r_mun, v_t_type, v_notes = row
    k_tr_id, k_time, k_amount, k_curr, k_s_acc, k_r_acc, k_s_country, k_s_mun, k_r_country, k_r_mun, k_t_type, k_notes = idx


    if v_tr_id or v_time or v_amount or v_curr or v_s_acc or v_r_acc or v_s_country or v_s_mun or v_r_country or v_r_mun or v_t_type is None:
        for key, value in (idx, row):
            
        error_builder.append({
                
            "error_message" : "One or more columns witt forbidden None"})
        print("there were errors")
    # display(error_builder)

# %%
for idx, row in df.iterrows():
    # print(type(row))
    # print(row.index)
    # for index_n, indexname in enumerate(row.index):
        # print(row[indexname])
        # print(row.index[index_n])
    # if idx >= 0:
    #     return

    none_check(row)
# Out:
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# there we errors
# ...

# %%
print(len(row))
# Out:
# 12

# %%
test = []
print(test)
test.append("cirkus")
tor = "torsås"
print(test)
test.extend([tor, "flemingsberg", "givetvis", tor])
print(test)
# Out:
# []
# ['cirkus']
# ['cirkus', 'torsås', 'flemingsberg', 'givetvis', 'torsås']

# %%
error_messages = []
